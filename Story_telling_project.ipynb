# %% [markdown]
# # What makes people happy? Can you find Dytopia?
#
# The `World Happiness Report` is a landmark survey of the state of global happiness that ranks 156 countries by how happy their citizens perceive themselves to be. Over the last year’s, `World Happiness Report` focuses on happiness and the community: how happiness has evolved over the past dozen years, with a focus on the technologies, social norms, conflicts and government policies that have driven those changes.
#
# ![image.png](attachment:image.png)
#
#
# **Dataset information**
#
#     The information in the datasets is based on answers to the most life evaluation address inquired within the survey. This address, known as the Cantril step, asks respondents to think of a step with the most excellent conceivable life for them being a 10 and the most exceedingly bad conceivable life being a and to rate their claim current lives on that scale.
#
#
# The Happiness Score is explained by the following factors:
#
# - `Overall rank`: happiness rank of the different countries
# - `Country o region`
# - `Score`:  is a national average of the responses to the main life evaluation question asked in the Gallup World Poll (GWP), which uses the Cantril Ladder. Ranges from [0-10]
# - `GDP per capita`
# - `Healthy Life Expectancy`: score that goes from [0-1], being 1 the ones that have more confidence in terms of healthy life
# - `Social support`: it indicates how people are appreciating the social support by governments, and it that ranges from [0-2]
# - `Freedom to make life choices` score that ranges from 0 to 1, being 1 the ones that feel more free
# - `Generosity`:score that ranges from 0 to 1, being 1 the ones that feel more generosity
# - `Perceptions of corruption`: perception of corruption on the country that it goes from  0 to 1. The higher this value is the lower perception of corruption
# - `year`
#
#
# >dataset: `Ex2.2._Happiness-Score.csv`

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px 
import plotly.graph_objs as go

import warnings
warnings.filterwarnings('ignore')

# %%
# Exercise 1.Tell a story with your dataset, to try to answer the following question:

"Which factors are more important to live a happier life? As a result, people and countries can focus on the more significant factors to achieve a higher happiness level "

# To achieve this goal use the different funcionalities from 
# the visualization libraries that you have seen in the module
# Out:
# 'Which factors are more important to live a happier life? As a result, people and countries can focus on the more significant factors to achieve a higher happiness level '

# %%
data = pd.read_csv('../../datasets/Students_turn/Ex2.2._Happiness-Score.csv')

# %%
data.head(20)
# Out:
#     Unnamed: 0.1  Unnamed: 0  Overall rank     Country or region  Score  \
# 0              0           0             1               Finland  7.632
# 1              1           1             2                Norway  7.594
# 2              2           2             3               Denmark  7.555
# 3              3           3             4               Iceland  7.495
# 4              4           4             5           Switzerland  7.487
# 5              5           5             6           Netherlands  7.441
# 6              6           6             7                Canada  7.328
# 7              7           7             8           New Zealand  7.324
# 8              8           8             9                Sweden  7.314
# 9              9           9            10             Australia  7.272
# 10            10          10            11        United Kingdom  7.190
# 11            11          11            12               Austria  7.139
# ...

# %%
#checking the ranking for Portugal 
data[(data["Country or region"] == "Portugal")]
# Out:
#      Unnamed: 0.1  Unnamed: 0  Overall rank Country or region  Score  \
# 76             76          76            77          Portugal  5.410
# 221           221          65            66          Portugal  5.693
#
#      GDP per capita  Social support  Healthy life expectancy  \
# 76            1.188           1.429                      NaN
# 221           1.221           1.431                      NaN
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  year
# 76                          0.562       0.055                      0.017  2018
# 221                         0.508       0.047                      0.025  2019

# %%
#checking the ranking for the UK
data[(data["Country or region"] == "United Kingdom")]
# Out:
#      Unnamed: 0.1  Unnamed: 0  Overall rank Country or region  Score  \
# 10             10          10            11    United Kingdom  7.190
# 170           170          14            15    United Kingdom  7.054
#
#      GDP per capita  Social support  Healthy life expectancy  \
# 10            1.244           1.433                      NaN
# 170           1.333           1.538                      NaN
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  year
# 10                          0.464       0.262                      0.082  2018
# 170                         0.450       0.348                      0.278  2019

# %%
#checking the ranking for HK
data[(data["Country or region"] == "Hong Kong")]
# Out:
#      Unnamed: 0.1  Unnamed: 0  Overall rank Country or region  Score  \
# 75             75          75            76         Hong Kong   5.43
# 231           231          75            76         Hong Kong   5.43
#
#      GDP per capita  Social support  Healthy life expectancy  \
# 75            1.405           1.290                      NaN
# 231           1.438           1.277                      NaN
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  year
# 75                          0.524       0.246                      0.291  2018
# 231                         0.440       0.258                      0.287  2019

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312 entries, 0 to 311
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0.1                  312 non-null    int64
#  1   Unnamed: 0                    312 non-null    int64
#  2   Overall rank                  312 non-null    int64
#  3   Country or region             312 non-null    object
#  4   Score                         312 non-null    float64
#  5   GDP per capita                312 non-null    float64
#  6   Social support                312 non-null    float64
#  7   Healthy life expectancy       7 non-null      float64
#  8   Freedom to make life choices  312 non-null    float64
#  9   Generosity                    312 non-null    float64
#  10  Perceptions of corruption     311 non-null    float64
#  11  year                          312 non-null    int64
# dtypes: float64(7), int64(4), object(1)
# ...

# %% [markdown]
# # check IDs

# %%
# the first two columns are duplicates so we don't need them
data = data.drop(axis=1, labels=["Unnamed: 0","Unnamed: 0.1"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312 entries, 0 to 311
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  312 non-null    int64
#  1   Country or region             312 non-null    object
#  2   Score                         312 non-null    float64
#  3   GDP per capita                312 non-null    float64
#  4   Social support                312 non-null    float64
#  5   Healthy life expectancy       7 non-null      float64
#  6   Freedom to make life choices  312 non-null    float64
#  7   Generosity                    312 non-null    float64
#  8   Perceptions of corruption     311 non-null    float64
#  9   year                          312 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 24.5+ KB

# %%
healthy_life_exp_null = data["Healthy life expectancy"].isnull().sum()
healthy_life_exp_null
# Out:
# 305

# %%
percentageofnull_hle = healthy_life_exp_null / len(data)*100
percentageofnull_hle
# Out:
# 97.75641025641025

# %%
#missing values heatmap

sns.set(rc={'figure.figsize':(15, 5)})
sns.heatmap(data.isnull(), yticklabels=False, cbar=True, cmap='coolwarm')

plt.show()

# %%
def percentage_nullValues(data):
    """
    Function that calculates the percentage of missing values in every column of your dataset
    input: data --> dataframe
    """
    null_perc = round(data.isnull().sum() / data.shape[0],3) * 100.00
    null_perc = pd.DataFrame(null_perc, columns=['Percentage_NaN'])
    null_perc= null_perc.sort_values(by = ['Percentage_NaN'], ascending = False)
    return null_perc

# %%
def select_threshold(data, thr):
    """
    Function that  calculates the percentage of missing values in every column of your dataset
    input: data --> dataframe
    
    """
    null_perc = percentage_nullValues(data)
      
    col_keep = null_perc[null_perc['Percentage_NaN'] < thr]
    col_keep = list(col_keep.index)
    print('Columns to keep:',len(col_keep))
    print('Those columns have a percentage of NaN less than', str(thr), ':')
    print(col_keep)
    data_c= data[col_keep]
    
    return data_c

# %%
# using pre made function to check which columns have more than 5% missing values

missing = select_threshold(data,5)
# Out:
# Columns to keep: 9
# Those columns have a percentage of NaN less than 5 :
# ['Perceptions of corruption', 'Overall rank', 'Country or region', 'Score', 'GDP per capita', 'Social support', 'Freedom to make life choices', 'Generosity', 'year']

# %%
# dropping healthy life expectancy as it's mostly empty
data = data.drop(axis=1, labels=["Healthy life expectancy"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312 entries, 0 to 311
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  312 non-null    int64
#  1   Country or region             312 non-null    object
#  2   Score                         312 non-null    float64
#  3   GDP per capita                312 non-null    float64
#  4   Social support                312 non-null    float64
#  5   Freedom to make life choices  312 non-null    float64
#  6   Generosity                    312 non-null    float64
#  7   Perceptions of corruption     311 non-null    float64
#  8   year                          312 non-null    int64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 22.1+ KB

# %%
def fill_na(data):
    """
    Function to fill NaN with mode (categorical variabls) and mean (numerical variables)
    input: data -> df
    """
    for column in data:
        if data[column].dtype != 'object':
            data[column] = data[column].fillna(data[column].mean())  
        else:
            data[column] = data[column].fillna(data[column].mode()[0]) 
    print('Number of missing values on your dataset are')
    print()
    print(data.isnull().sum())
    return data

# %%
# using pre made function to fill one missing value
data = fill_na(data)
# Out:
# Number of missing values on your dataset are
#
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# year                            0
# dtype: int64

# %%
data.head(5)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  year
# 0                         0.681       0.202                      0.393  2018
# 1                         0.686       0.286                      0.340  2018
# 2                         0.683       0.284                      0.408  2018
# 3                         0.677       0.353                      0.138  2018
# 4                         0.660       0.256                      0.357  2018

# %% [markdown]
# # Duplicates

# %%
len(data)-len(data.drop_duplicates())
# this is zero so we don't have duplicates
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312 entries, 0 to 311
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  312 non-null    int64
#  1   Country or region             312 non-null    object
#  2   Score                         312 non-null    float64
#  3   GDP per capita                312 non-null    float64
#  4   Social support                312 non-null    float64
#  5   Freedom to make life choices  312 non-null    float64
#  6   Generosity                    312 non-null    float64
#  7   Perceptions of corruption     312 non-null    float64
#  8   year                          312 non-null    int64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 22.1+ KB

# %% [markdown]
# # Numerical Outliers

# %%
data.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    312.000000  312.000000      312.000000      312.000000
# mean      78.500000    5.391506        0.898298        1.211026
# std       45.104737    1.114631        0.394592        0.300310
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.514250        0.609500        1.055750
# 50%       78.500000    5.379500        0.960000        1.265500
# 75%      117.250000    6.176000        1.219500        1.457500
# max      156.000000    7.769000        2.096000        1.644000
#
#        Freedom to make life choices  Generosity  Perceptions of corruption  \
# count                    312.000000  312.000000                 312.000000
# mean                       0.423538    0.182926                   0.111299
# std                        0.156024    0.096739                   0.095212
# min                        0.000000    0.000000                   0.000000
# ...

# %%
num_var = data.select_dtypes(include=['int', 'float']).columns

# %%
data_num = data[num_var]

# %%
data_num = data_num.drop(axis=1, labels=["year"])

# %%
fig = px.box(data_num,points="suspectedoutliers")
fig.show()
# Out:
# <div>                            <div id="cb6b7031-4d5d-40d2-97be-5d644a358bfc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb6b7031-4d5d-40d2-97be-5d644a358bfc")) {                    Plotly.newPlot(                        "cb6b7031-4d5d-40d2-97be-5d644a358bfc",                        [{"alignmentgroup": "True", "boxpoints": "suspectedoutliers", "hovertemplate": "variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["Overall rank", "Overall rank", "Overall rank", "Overall rank", "Overall rank", "Overall rank", "Overall rank", "Overall rank", "Overall rank", "Overall rank", "Overall rank", "Over
# ...

# %%
def outliers_loop(df_num):
    """
    function to check the shape of the data if outliers were dropped from each numerical variable
    
    """
    for item in np.arange(0,len(df_num.columns)):
        if item == 0:
            df_c = outlier_treatment(df_num, df_num.columns[item])
        else:
            df_c = outlier_treatment(df_c, df_num.columns[item]) 
    return df_c

# %%
# using pre made fucntion to drop values outside IQR*1.5
df_clean = outliers_loop(data_num)
# Out:
# Shape of the raw data: (312, 7)
# ..................
# Shape of the cleaned data: (312, 7)
# Shape of the raw data: (312, 7)
# ..................
# Shape of the cleaned data: (312, 7)
# Shape of the raw data: (312, 7)
# ..................
# Shape of the cleaned data: (312, 7)
# Shape of the raw data: (312, 7)
# ..................
# Shape of the cleaned data: (305, 7)
# Shape of the raw data: (305, 7)
# ..................
# Shape of the cleaned data: (301, 7)
# Shape of the raw data: (301, 7)
# ..................
# Shape of the cleaned data: (297, 7)
# Shape of the raw data: (297, 7)
# ..................
# Shape of the cleaned data: (264, 7)

# %%
#% of rows we would be dropping
round((1-len(df_clean)/len(data))*100,2)
# we think this is too much data to lose so decided to keep them
# Out:
# 15.38

# %% [markdown]
# # Further observations

# %% [markdown]
#  year: only data for 2 years: 2018 and 2019

# %%
data.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  year
# 0                         0.681       0.202                      0.393  2018
# 1                         0.686       0.286                      0.340  2018
# 2                         0.683       0.284                      0.408  2018
# 3                         0.677       0.353                      0.138  2018
# 4                         0.660       0.256                      0.357  2018

# %%
# looks like some countries only have values for one year

data.pivot_table(index=['Country or region'], columns=["year"], values='Overall rank', aggfunc='count', margins=True)
# Out:
# year                2018   2019  All
# Country or region
# Afghanistan          1.0    1.0    2
# Albania              1.0    1.0    2
# Algeria              1.0    1.0    2
# Angola               1.0    NaN    1
# Argentina            1.0    1.0    2
# ...                  ...    ...  ...
# Vietnam              1.0    1.0    2
# Yemen                1.0    1.0    2
# Zambia               1.0    1.0    2
# Zimbabwe             1.0    1.0    2
# All                156.0  156.0  312
#
# [161 rows x 3 columns]

# %%
# some countries have two ranks and others only have 1 so we are doing the mean rank to be able to compare

newdata = data.groupby(["Country or region"])["Overall rank"].mean().to_frame()

# %%
newdata["Average rank"] = newdata["Overall rank"]

# %%
newdata.head(15)
# Out:
#                    Overall rank  Average rank
# Country or region
# Afghanistan               149.5         149.5
# Albania                   109.5         109.5
# Algeria                    86.0          86.0
# Angola                    142.0         142.0
# Argentina                  38.0          38.0
# Armenia                   122.5         122.5
# Australia                  10.5          10.5
# Austria                    11.0          11.0
# Azerbaijan                 88.5          88.5
# Bahrain                    40.0          40.0
# Bangladesh                120.0         120.0
# Belarus                    77.0          77.0
# Belgium                    17.0          17.0
# Belize                     49.0          49.0
# Benin                     119.0         119.0

# %%
newdata = newdata.drop(axis=1, labels="Overall rank")

# %%
newdata.head(5)
# Out:
#                    Average rank
# Country or region
# Afghanistan               149.5
# Albania                   109.5
# Algeria                    86.0
# Angola                    142.0
# Argentina                  38.0

# %%
df = pd.merge(data, newdata, on="Country or region")

# %%
df.head(5)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             1           Finland  7.769           1.340           1.587
# 2             2            Norway  7.594           1.456           1.582
# 3             3            Norway  7.554           1.488           1.582
# 4             3           Denmark  7.555           1.351           1.590
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  year  \
# 0                         0.681       0.202                      0.393  2018
# 1                         0.596       0.153                      0.393  2019
# 2                         0.686       0.286                      0.340  2018
# 3                         0.603       0.271                      0.341  2019
# 4                         0.683       0.284                      0.408  2018
#
#    Average rank
# 0           1.0
# 1           1.0
# ...

# %%
df.shape
# Out:
# (312, 10)

# %% [markdown]
# # Correlation Heatmap

# %%
df.corr()
# Out:
#                               Overall rank     Score  GDP per capita  \
# Overall rank                  1.000000e+00 -0.990325       -0.803757
# Score                        -9.903250e-01  1.000000        0.797977
# GDP per capita               -8.037573e-01  0.797977        1.000000
# Social support               -7.523724e-01  0.761080        0.713293
# Freedom to make life choices -5.264284e-01  0.539897        0.342953
# Generosity                   -7.623314e-02  0.106645       -0.044788
# Perceptions of corruption    -3.605530e-01  0.394336        0.303978
# year                         -2.511206e-14  0.014009        0.017386
# Average rank                  9.957068e-01 -0.987102       -0.807269
#
#                               Social support  Freedom to make life choices  \
# Overall rank                       -0.752372                     -0.526428
# Score                               0.761080                      0.539897
# ...

# %%
plt.figure(figsize=(16, 6)) 
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, cmap='coolwarm') 
heatmap.set_title('Correlation Heatmap ', fontdict={'fontsize':12}, pad=12)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap ')

# %%
# we dont need to see overall rank, year

# %%
dfforcorr = df.drop(axis=1, labels=["Overall rank", "year"])

# %%
dfforcorr.head(2)
# Out:
#   Country or region  Score  GDP per capita  Social support  \
# 0           Finland  7.632           1.305           1.592
# 1           Finland  7.769           1.340           1.587
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.681       0.202                      0.393
# 1                         0.596       0.153                      0.393
#
#    Average rank
# 0           1.0
# 1           1.0

# %%
plt.figure(figsize=(20, 6)) 
heatmap = sns.heatmap(dfforcorr.corr(), vmin=-1, vmax=1, annot=True, cmap='coolwarm') 
heatmap.set_title('Correlation Heatmap ', fontdict={'fontsize':12}, pad=12)
plt.savefig("corrmap.png")

# %%
# mainly the 3 correlated ones are GDP, Social Support, Freedom to make life choices - focusing our efforts on those
# generosity and perceptions of corruption have low corr scores
# to note that GDP and social support are related to each other

# %%
score = data.groupby(by=["Country or region"], as_index=False)["Score"].mean()
score
# Out:
#     Country or region   Score
# 0         Afghanistan  3.4175
# 1             Albania  4.6525
# 2             Algeria  5.2530
# 3              Angola  3.7950
# 4           Argentina  6.2370
# ..                ...     ...
# 155         Venezuela  4.7565
# 156           Vietnam  5.1390
# 157             Yemen  3.3675
# 158            Zambia  4.2420
# 159          Zimbabwe  3.6775
#
# [160 rows x 2 columns]

# %%
data["Overall rank"].value_counts()
# Out:
# 1      2
# 108    2
# 101    2
# 102    2
# 103    2
#       ..
# 53     2
# 54     2
# 55     2
# 56     2
# 156    2
# Name: Overall rank, Length: 156, dtype: int64

# %% [markdown]
# ## Score by country map

# %%
#score map
fig1 = px.choropleth(df, locations="Country or region", color="Score", locationmode='country names', range_color=[1,10], color_continuous_scale="sunset")
fig1.update_layout(title='Comparison by country') 
fig1.show()

fig1.write_image("img_name.png")
# Out:
# <div>                            <div id="a40a1d23-710a-4a30-8d80-7573528cc454" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a40a1d23-710a-4a30-8d80-7573528cc454")) {                    Plotly.newPlot(                        "a40a1d23-710a-4a30-8d80-7573528cc454",                        [{"coloraxis": "coloraxis", "geo": "geo", "hovertemplate": "Country or region=%{location}<br>Score=%{z}<extra></extra>", "locationmode": "country names", "locations": ["Finland", "Finland", "Norway", "Norway", "Denmark", "Denmark", "Iceland", "Iceland", "Switzerland", "Switzerland", "Netherlands", "Netherlands", "Canada", "Canada", "New Zealand", "New Zealand", "Sweden", "Sweden", "Australia", "Australia", "United Kingdom", "United Kingdom", "Austria", "Austria", 
# ...

# %%
#top3
df.sort_values(by="Average rank",ascending=True).head(20)
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 0              1           Finland  7.632           1.305           1.592
# 1              1           Finland  7.769           1.340           1.587
# 2              2            Norway  7.594           1.456           1.582
# 3              3            Norway  7.554           1.488           1.582
# 4              3           Denmark  7.555           1.351           1.590
# 5              2           Denmark  7.600           1.383           1.573
# 6              4           Iceland  7.495           1.343           1.644
# 7              4           Iceland  7.494           1.380           1.624
# 10             6       Netherlands  7.441           1.361           1.488
# 11             5       Netherlands  7.488           1.396           1.522
# 8              5       Switzerland  7.487           1.420           1.549
# 9              6       Switzerland  7.480           1.452           1.526
# ...

# %%
#bottom3
df.sort_values(by="Average rank",ascending=True).tail(6)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 300           153                  Tanzania  3.303           0.455
# 301           153                  Tanzania  3.231           0.476
# 302           154               South Sudan  3.254           0.337
# 303           156               South Sudan  2.853           0.306
# 304           155  Central African Republic  3.083           0.024
# 305           155  Central African Republic  3.083           0.026
#
#      Social support  Freedom to make life choices  Generosity  \
# 300           0.991                         0.481       0.270
# 301           0.885                         0.417       0.276
# 302           0.608                         0.112       0.224
# 303           0.575                         0.010       0.202
# 304           0.000                         0.305       0.218
# 305           0.000                         0.225       0.235
#
#      Perceptions of corruption  year  Average rank
# ...

# %% [markdown]
# # GDP map

# %%
#GDP map
fig2 = px.choropleth(df, locations="Country or region", color="GDP per capita", locationmode='country names', range_color=[0,2.1], color_continuous_scale="sunset")
fig2.update_layout(title='Distribution GDP') 
fig2.show()
# Out:
# <div>                            <div id="83e3bd32-2a35-415e-8080-bc3e6e0d4c72" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83e3bd32-2a35-415e-8080-bc3e6e0d4c72")) {                    Plotly.newPlot(                        "83e3bd32-2a35-415e-8080-bc3e6e0d4c72",                        [{"coloraxis": "coloraxis", "geo": "geo", "hovertemplate": "Country or region=%{location}<br>GDP per capita=%{z}<extra></extra>", "locationmode": "country names", "locations": ["Finland", "Finland", "Norway", "Norway", "Denmark", "Denmark", "Iceland", "Iceland", "Switzerland", "Switzerland", "Netherlands", "Netherlands", "Canada", "Canada", "New Zealand", "New Zealand", "Sweden", "Sweden", "Australia", "Australia", "United Kingdom", "United Kingdom", "Austria", "A
# ...

# %% [markdown]
# # Scatterplots

# %%
# SOCIAL SUPPORT
sns.scatterplot(data=df, x="Social support", y="Score", hue="Score", size="Score", sizes=(2, 200),palette="coolwarm",legend=True).set(title='Relationship between Happiness Score and Social Support')
# Out:
# [Text(0.5, 1.0, 'Relationship between Happiness Score and Social Support')]

# %%
# GDP
sns.scatterplot(data=df, x="GDP per capita", y="Score", hue="Score", size="Score", sizes=(2, 200),palette="coolwarm",legend=True).set(title='Relationship between Happiness Score and GDP per capita')
# Out:
# [Text(0.5, 1.0, 'Relationship between Happiness Score and GDP per capita')]

# %%
# Freedom to make life choices
sns.scatterplot(data=df, x="Freedom to make life choices", y="Score", hue="Score", size="Score", sizes=(2, 200),palette="coolwarm",legend=True).set(title='Relationship between Happiness Score and Freedom to make life choices')
# Out:
# [Text(0.5, 1.0, 'Relationship between Happiness Score and Freedom to make life choices')]

# %%
#histogram
#Step 1: Create the traces of the plots 
fig = px.histogram(df, x="Freedom to make life choices") 
# Step 2: Update the layout of the plot 
fig.update_layout(title_text='Distribution to make life choices ') 
# axes styling fig.update_xaxes(title= 'Freedom to make life choices',ticklen= 5,zeroline= False) 
fig.update_yaxes(title= 'Count',ticklen= 5,zeroline= False) 
fig.show()
# Out:
# <div>                            <div id="8fe0267c-cd07-4470-b955-5b46345d4328" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8fe0267c-cd07-4470-b955-5b46345d4328")) {                    Plotly.newPlot(                        "8fe0267c-cd07-4470-b955-5b46345d4328",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "Freedom to make life choices=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [0.6809999999999999, 0.596, 0.6859999999999999, 0.603, 0.6829999999999999, 0.5920000000000001, 0.677, 0.591, 0.66, 0.5720000000000001, 0.638, 0.557, 0.653, 0.584, 0.669, 0.585, 0.659, 0.574, 
# ...

# %% [markdown]
# # Distplots

# %%
sns.distplot(df['Freedom to make life choices'],color='c')
# Out:
# <AxesSubplot:xlabel='Freedom to make life choices', ylabel='Density'>

# %%
sns.distplot(df['GDP per capita'],color='c')
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='Density'>

# %%
sns.distplot(df['Social support'],color='c')
# Out:
# <AxesSubplot:xlabel='Social support', ylabel='Density'>

# %% [markdown]
# # Histograms with outliers box

# %%
#social support

f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})
mean=df['Social support'].mean()
median=df['Social support'].median()
sns.boxplot(data=df, x="Social support", ax=ax_box, color='c')
ax_box.axvline(mean, color='r', linestyle='--')
ax_box.axvline(median, color='g', linestyle='-')
sns.histplot(data=df, x="Social support", ax=ax_hist, kde=True, color='c')
ax_hist.axvline(mean, color='r', linestyle='--', label="Mean")
ax_hist.axvline(median, color='g', linestyle='-', label="Median")
ax_hist.legend()
ax_box.set(xlabel='')
plt.show()

# %%
#GDP per capita

f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})
mean=df['GDP per capita'].mean()
median=df['GDP per capita'].median()
sns.boxplot(data=df, x="GDP per capita", ax=ax_box, color='c')
ax_box.axvline(mean, color='r', linestyle='--')
ax_box.axvline(median, color='g', linestyle='-')
sns.histplot(data=df, x="GDP per capita", ax=ax_hist, kde=True, color='c')
ax_hist.axvline(mean, color='r', linestyle='--', label="Mean")
ax_hist.axvline(median, color='g', linestyle='-', label="Median")
ax_hist.legend()
ax_box.set(xlabel='')
plt.show()

# %%
#Freedom to make life choices

f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})
mean=df['Freedom to make life choices'].mean()
median=df['Freedom to make life choices'].median()
sns.boxplot(data=df, x="Freedom to make life choices", ax=ax_box, color='c')
ax_box.axvline(mean, color='r', linestyle='--')
ax_box.axvline(median, color='g', linestyle='-')
sns.histplot(data=df, x="Freedom to make life choices", ax=ax_hist, kde=True, color='c')
ax_hist.axvline(mean, color='r', linestyle='--', label="Mean")
ax_hist.axvline(median, color='g', linestyle='-', label="Median")
ax_hist.legend()
ax_box.set(xlabel='')
plt.show()

# %%
df.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'year', 'Average rank'],
#       dtype='object')

# %%
df.skew()
# Out:
# Overall rank                    0.000000
# Score                           0.013021
# GDP per capita                 -0.298942
# Social support                 -1.102203
# Freedom to make life choices   -0.631564
# Generosity                      0.803631
# Perceptions of corruption       1.660554
# year                            0.000000
# Average rank                   -0.006501
# dtype: float64

# %% [markdown]
#  If the skewness is between -0.5 and 0.5, the data are fairly symmetrical. ·
#  If the skewness is between -1 and — 0.5 or between 0.5 and 1, the data are moderately skewed. ·
#  If the skewness is less than -1 or greater than 1, the data are highly skewed
